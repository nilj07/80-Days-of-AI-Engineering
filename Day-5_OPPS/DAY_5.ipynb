# %% [markdown]
# # **Class and Object**

# %%
class student:
  collage = 'SIT'
  def __init__(self,name,age,grade):
    self.name = name
    self.age = age
    self.grade = grade


s1 = student('Nilesh',22,'A')
s2 = student('Sagar',23,'B')

# %%
s1.collage
# Out:
# 'SIT'

# %% [markdown]
# # **INHERITANCE (REUSE CODE)**

# %%
class animal:
  def speak(self):
    print('animal sound')

class dog(animal):
  def speak(self):
    print('bark')

d = dog()
d.speak()
# Out:
# bark
